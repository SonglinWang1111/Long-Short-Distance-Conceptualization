# %% [markdown]
# ## LLM Long-/Short- Distance Conceptualization Part I

# %% [markdown]
# This experiment tests LLMs' conceptualization on distance considering different scenarios.

# %% [markdown]
# ### Libraries

# %%
from openai import OpenAI, RateLimitError, APIError, APITimeoutError, AuthenticationError, BadRequestError, NotFoundError
from google.api_core.exceptions import ResourceExhausted, RetryError, DeadlineExceeded
import google.generativeai as genai

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import time
import os
import ast
from tqdm import tqdm
import requests

# %% [markdown]
# ### Layout

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_seq_items', None)

# %% [markdown]
# ### Pre-defined variables

# %% [markdown]
# Anything you want to set as prior, such as max token, temperature, top-p, logprob, etc.

# %%
MAX_TOKEN = 16
TEMPERATURE = 0.7

# %% [markdown]
# ### General commands for getting response

# %% [markdown]
# We employ 3 different models: gpt-5.1, gemini-2.5-flash, and deepseek-3.2-chat via API provided by them. For all models we consider the same temperature (0.7) and run each experiment for 30 times to get valid threshold.

# %%
def api_def(provider):
    # API keys are hidden in another file
    with open('api.txt', 'r', encoding='utf-8') as file:
        lines = [line.strip() for line in file.readlines()]

        # Different LLMs need different kinds of command
        if provider == 'chatgpt':
            client = OpenAI(api_key=str(lines[0]), base_url="https://api.openai.com/v1")
            return client
        
        elif provider == 'deepseek':
            client = OpenAI(api_key=str(lines[1]), base_url="https://api.deepseek.com")
            return client
        
        elif provider == 'gemini':
            genai.configure(api_key=str(lines[4]))

# %%
def get_completion(prompt, provider, model):
    messages = [{"role": "system", "content": "You are participating in our social survey. Please simply answer the question without deep thinking"},
               {"role": "user", "content": prompt}]

    # Different LLMs need different kinds of command
    if provider == 'gpt':
        client = api_def('chatgpt')
        response = client.responses.create(
            model=model,
            input=messages,
            temperature=TEMPERATURE,
            max_output_tokens = MAX_TOKEN
            # reasoning_effort = high
        )
        return response.output_text
        
    elif provider == 'ds':
        client = api_def('deepseek')
        response = client.chat.completions.create(
            model=model,
            messages=messages,
            temperature=TEMPERATURE
        )
        return response.choices[0].message.content

    elif provider == 'gemini':
        api_def('gemini')
        model_gemini = genai.GenerativeModel(model)
        response = model_gemini.generate_content(
            prompt,
            generation_config={"temperature": TEMPERATURE, "max_output_tokens": 100}
        )
        return response.text

# %%
def QA_1(provider, model, dist):
    prompt = f"""
    Please determine if {dist} kilometers qualifies as a "long distance" or a 'short distance'. \
    Output only one character: If it qualifies as a 'long distance', please return 'Y', while if it qualifies as \
    a 'short distance', return 'N'. We don't have any other category in this scheme like "medium distance". \n
    Do not infer any missing information. Output only the single character without any other thing such as \
    explanations, opinions or meta-comments. 
    """
    response = get_completion(prompt, provider, model)
    return response

# %%
def QA_2(provider, model, dist):
    prompt = f"""
    Please determine if a {dist}-kilometer commute qualifies as a 'long-distance commute' or a 'short-distance commute'. \
    Output only one character: If it qualifies as a 'long-distance commute', please return 'Y', while if it \
    qualifies as a 'short-distance commute', please return 'N'. We don't have any other category in this scheme like "medium-distance commute". \n
    Do not infer any missing information. Output only the single character without any other thing such as \
    explanations, opinions or meta-comments.
    """
    response = get_completion(prompt, provider, model)
    return response

# %%
def QA_3(provider, model, dist):
    prompt = f"""
    Please determine if a {dist}-kilometer human migration qualifies as a 'long-distance human migration' \
    or a 'short-distance human migration'. \
    Output only one character: If it qualifies as a 'long-distance human migration', please return 'Y', \
    while if it qualifies as a 'short-distance human migration', please return 'N'. \
    We don't have any other category in this scheme like "medium-distance human migration". \n
    Do not infer any missing information. Output only the single character without any other thing such as \
    explanations, opinions or meta-comments.
    """
    response = get_completion(prompt, provider, model)
    return response

# %%
def QA_4(provider, model, dist):
    prompt = f"""
    Please determine if a {dist}-kilometer human migration under the influence of environmental or climate change \
    qualifies as a 'long-distance human migration' or a 'short-distance human migration'. \
    Output only one character: If it qualifies as a 'long-distance human migration', please return 'Y', \
    while if it qualifies as a 'short-distance human migration', please return 'N'. \
    We don't have any other category in this scheme like "medium-distance human migration". \n
    Do not infer any missing information. Output only the single character without any other thing such as \
    explanations, opinions or meta-comments.
    """
    response = get_completion(prompt, provider, model)
    return response

# %%
def QA_5(provider, model, dist):
    prompt = f"""
    Please determine if a {dist}-kilometer seasonal human migration under the influence of environmental or \
    climate change qualifies as a 'long-distance human migration' or a 'short-distance human migration'. \
    Output only one character: If it qualifies as a 'long-distance human migration', please return 'Y', \
    while if it qualifies as a 'short-distance human migration', please return 'N'. \
    We don't have any other category in this scheme like "medium-distance human migration". \n
    Do not infer any missing information. Output only the single character without any other thing such as \
    explanations, opinions or meta-comments.
    """
    response = get_completion(prompt, provider, model)
    return response

# %%
def QA_6(provider, model, dist):
    prompt = f"""
    Please determine if a {dist}-kilometer temporal human migration under the influence of environmental or \
    climate change qualifies as a 'long-distance human migration' or a 'short-distance human migration'. \
    Output only one character: If it qualifies as a 'long-distance human migration', please return 'Y', \
    while if it qualifies as a 'short-distance human migration', please return 'N'. \
    We don't have any other category in this scheme like "medium-distance human migration". \n
    Do not infer any missing information. Output only the single character without any other thing such as \
    explanations, opinions or meta-comments.
    """
    response = get_completion(prompt, provider, model)
    return response

# %%
def QA_7(provider, model, dist):
    prompt = f"""
    Please determine if a {dist}-kilometer permanent human migration under the influence of environmental or \
    climate change qualifies as a 'long-distance human migration' or a 'short-distance human migration'. \
    Output only one character: If it qualifies as a 'long-distance human migration', please return 'Y', \
    while if it qualifies as a 'short-distance human migration', please return 'N'. \
    We don't have any other category in this scheme like "medium-distance human migration". \n
    Do not infer any missing information. Output only the single character without any other thing such as \
    explanations, opinions or meta-comments.
    """
    response = get_completion(prompt, provider, model)
    return response

# %%
def QA_8(provider, model, dist):
    prompt = f"""
    Please determine if a {dist}-kilometer internal human migration under the influence of environmental or \
    climate change qualifies as a 'long-distance human migration' or a 'short-distance human migration'. \
    Output only one character: If it qualifies as a 'long-distance human migration', please return 'Y', \
    while if it qualifies as a 'short-distance human migration', please return 'N'. \
    We don't have any other category in this scheme like "medium-distance human migration". \n
    Do not infer any missing information. Output only the single character without any other thing such as \
    explanations, opinions or meta-comments.
    """
    response = get_completion(prompt, provider, model)
    return response

# %%
def QA_9(provider, model, dist):
    prompt = f"""
    Please determine if a {dist}-kilometer international human migration under the influence of environmental or \
    climate change qualifies as a 'long-distance human migration' or a 'short-distance human migration'. \
    Output only one character: If it qualifies as a 'long-distance human migration', please return 'Y', \
    while if it qualifies as a 'short-distance human migration', please return 'N'. \
    We don't have any other category in this scheme like "medium-distance human migration". \n
    Do not infer any missing information. Output only the single character without any other thing such as \
    explanations, opinions or meta-comments.
    """
    response = get_completion(prompt, provider, model)
    return response

# %%
def QA_to_df(provider, model, min_d, max_d, step, QA_number):
    results = []
    fail_count = 0
    dist = np.arange(min_d, max_d, step)

    for d in tqdm(dist):     
        for run_id in range(30):
            success = False
            while not success:
                try:
                    QA = globals()[f"QA_{QA_number}"]
                    result = {"answer": QA(provider, model, d)}
                    result["distance"] = d
                    result["model"] = model
                    result["run"] = run_id
                    results.append(result)
                    success = True
                except (RateLimitError, APIError, APITimeoutError, ResourceExhausted, ValueError) as e: # AuthenticationError, BadRequestError, NotFoundError
                    time.sleep(1)
                    fail_count = fail_count + 1
                    if fail_count >= 100:
                        raise ValueError(f"Can't get response: {result}, retried too many times") from e

    df = pd.DataFrame(results)
    df.to_csv(f"result/{provider}_Q{QA_number}.csv", index=False)
    
    return df

# %% [markdown]
# In all: 3 models, 9 scenarios, 1 temperature, 25 distances, 30 runs. In sum we need to call api for 20250 times, and will get a final result containing 20250 rows.

# %%
gpt51_1 = QA_to_df('gpt', 'gpt-5.1', 2, 52, 2, 1)
# Out:
# 100%|██████████| 25/25 [16:24<00:00, 39.37s/it]

# %%
gpt51_2 = QA_to_df('gpt', 'gpt-5.1', 2, 52, 2, 2)
# Out:
# 100%|██████████| 25/25 [16:56<00:00, 40.64s/it]

# %%
gpt51_3 = QA_to_df('gpt', 'gpt-5.1', 20, 520, 20, 3)
# Out:
# 100%|██████████| 25/25 [16:20<00:00, 39.22s/it]

# %%
gpt51_4 = QA_to_df('gpt', 'gpt-5.1', 20, 520, 20, 4)
# Out:
# 100%|██████████| 25/25 [16:57<00:00, 40.71s/it]

# %%
gpt51_5 = QA_to_df('gpt', 'gpt-5.1', 20, 520, 20, 5)
# Out:
# 100%|██████████| 25/25 [17:00<00:00, 40.84s/it]

# %%
gpt51_6 = QA_to_df('gpt', 'gpt-5.1', 20, 520, 20, 6)
# Out:
# 100%|██████████| 25/25 [14:39<00:00, 35.17s/it]

# %%
gpt51_7 = QA_to_df('gpt', 'gpt-5.1', 20, 520, 20, 7)
# Out:
# 100%|██████████| 25/25 [16:19<00:00, 39.18s/it]

# %%
gpt51_8 = QA_to_df('gpt', 'gpt-5.1', 20, 520, 20, 8)
# Out:
# 100%|██████████| 25/25 [16:42<00:00, 40.09s/it]

# %%
gpt51_9 = QA_to_df('gpt', 'gpt-5.1', 20, 520, 20, 9)
# Out:
# 100%|██████████| 25/25 [16:45<00:00, 40.23s/it]

# %%
ds32_1 = QA_to_df('ds', 'deepseek-chat', 2, 52, 2, 1)
# Out:
# 100%|██████████| 25/25 [16:09<00:00, 38.80s/it]

# %%
ds32_2 = QA_to_df('ds', 'deepseek-chat', 2, 52, 2, 2)
# Out:
# 100%|██████████| 25/25 [16:08<00:00, 38.73s/it]

# %%
ds32_3 = QA_to_df('ds', 'deepseek-chat', 20, 520, 20, 3)
# Out:
# 100%|██████████| 25/25 [16:43<00:00, 40.16s/it]

# %%
ds32_4 = QA_to_df('ds', 'deepseek-chat', 20, 520, 20, 4)
# Out:
# 100%|██████████| 25/25 [16:06<00:00, 38.67s/it]

# %%
ds32_5 = QA_to_df('ds', 'deepseek-chat', 20, 520, 20, 5)
# Out:
# 100%|██████████| 25/25 [16:40<00:00, 40.02s/it]

# %%
ds32_6 = QA_to_df('ds', 'deepseek-chat', 20, 520, 20, 6)
# Out:
# 100%|██████████| 25/25 [15:46<00:00, 37.87s/it]

# %%
ds32_7 = QA_to_df('ds', 'deepseek-chat', 20, 520, 20, 7)
# Out:
# 100%|██████████| 25/25 [16:33<00:00, 39.75s/it]

# %%
ds32_8 = QA_to_df('ds', 'deepseek-chat', 20, 520, 20, 8)
# Out:
# 100%|██████████| 25/25 [16:17<00:00, 39.12s/it]

# %%
ds32_9 = QA_to_df('ds', 'deepseek-chat', 20, 520, 20, 9)
# Out:
# 100%|██████████| 25/25 [16:22<00:00, 39.31s/it]

# %%
gemini_25_1 = QA_to_df('gemini', 'gemini-2.5-flash', 2, 52, 2, 1)
# Out:
# 100%|██████████| 25/25 [17:04<00:00, 40.99s/it]

# %%
gemini_25_2 = QA_to_df('gemini', 'gemini-2.5-flash', 2, 52, 2, 2)
# Out:
# 100%|██████████| 25/25 [16:44<00:00, 40.19s/it]

# %%
gemini_25_3 = QA_to_df('gemini', 'gemini-2.5-flash', 20, 520, 20, 3)
# Out:
# 100%|██████████| 25/25 [14:36<00:00, 35.08s/it]

# %%
gemini_25_4 = QA_to_df('gemini', 'gemini-2.5-flash', 20, 520, 20, 4)
# Out:
# 100%|██████████| 25/25 [14:15<00:00, 34.22s/it]

# %%
gemini_25_5 = QA_to_df('gemini', 'gemini-2.5-flash', 20, 520, 20, 5)
# Out:
# 100%|██████████| 25/25 [14:05<00:00, 33.82s/it]

# %%
gemini_25_6 = QA_to_df('gemini', 'gemini-2.5-flash', 20, 520, 20, 6)
# Out:
# 100%|██████████| 25/25 [14:50<00:00, 35.63s/it]

# %%
gemini_25_7 = QA_to_df('gemini', 'gemini-2.5-flash', 20, 520, 20, 7)
# Out:
# 100%|██████████| 25/25 [14:18<00:00, 34.36s/it]

# %%
gemini_25_8 = QA_to_df('gemini', 'gemini-2.5-flash', 20, 520, 20, 8)
# Out:
# 100%|██████████| 25/25 [15:23<00:00, 36.93s/it]

# %%
gemini_25_9 = QA_to_df('gemini', 'gemini-2.5-flash', 20, 520, 20, 9)
# Out:
# 100%|██████████| 25/25 [14:42<00:00, 35.31s/it]

# %% [markdown]
# ### Analysis

# %%
df_dict = {}

for file_name in os.listdir('result/'):
    if file_name.endswith('.csv'):
        file_path = os.path.join('result/', file_name)

        df = pd.read_csv(file_path)
        df['Q'] = file_name.replace('.csv', '')[-2:]
        df_name = file_name.replace('.csv', '')
        df_dict[df_name] = df

all_result = pd.concat(df_dict.values(), axis=0, ignore_index=True)

# %%
mapping_dict = {'N': 0, 'Y': 1}
all_result['answer_trans'] = all_result['answer'].map(mapping_dict).fillna(0.5)
all_result = all_result.drop(columns=['answer', 'run']).reset_index(drop=True)
grouped_result = all_result.groupby(['distance', 'model', 'Q']).agg({'answer_trans': 'mean'}).reset_index()
grouped_result
# Out:
#      distance             model   Q  answer_trans
# 0           2     deepseek-chat  Q1      0.000000
# 1           2     deepseek-chat  Q2      0.000000
# 2           2  gemini-2.5-flash  Q1      0.000000
# 3           2  gemini-2.5-flash  Q2      0.000000
# 4           2           gpt-5.1  Q1      0.000000
# 5           2           gpt-5.1  Q2      0.000000
# 6           4     deepseek-chat  Q1      0.033333
# 7           4     deepseek-chat  Q2      0.000000
# 8           4  gemini-2.5-flash  Q1      0.000000
# 9           4  gemini-2.5-flash  Q2      0.000000
# 10          4           gpt-5.1  Q1      0.000000
# 11          4           gpt-5.1  Q2      0.000000
# 12          6     deepseek-chat  Q1      0.066667
# 13          6     deepseek-chat  Q2      0.000000
# 14          6  gemini-2.5-flash  Q1      0.000000
# 15          6  gemini-2.5-flash  Q2      0.000000
# 16          6           gpt-5.1  Q1      0.000000
# 17          6           gpt-5.1  Q2      0.000000
# 18          8     deepseek-chat  Q1      0.066667
# 19          8     deepseek-chat  Q2      0.000000
# 20          8  gemini-2.5-flash  Q1      0.233333
# 21          8  gemini-2.5-flash  Q2      0.000000
# 22          8           gpt-5.1  Q1      0.600000
# 23          8           gpt-5.1  Q2      0.000000
# 24         10     deepseek-chat  Q1      1.000000
# 25         10     deepseek-chat  Q2      0.200000
# 26         10  gemini-2.5-flash  Q1      0.200000
# 27         10  gemini-2.5-flash  Q2      0.000000
# 28         10           gpt-5.1  Q1      0.466667
# 29         10           gpt-5.1  Q2      0.000000
# 30         12     deepseek-chat  Q1      1.000000
# 31         12     deepseek-chat  Q2      0.333333
# 32         12  gemini-2.5-flash  Q1      0.000000
# 33         12  gemini-2.5-flash  Q2      0.000000
# 34         12           gpt-5.1  Q1      0.000000
# 35         12           gpt-5.1  Q2      0.000000
# 36         14     deepseek-chat  Q1      0.933333
# 37         14     deepseek-chat  Q2      0.233333
# 38         14  gemini-2.5-flash  Q1      0.033333
# 39         14  gemini-2.5-flash  Q2      0.000000
# 40         14           gpt-5.1  Q1      0.000000
# 41         14           gpt-5.1  Q2      0.000000
# 42         16     deepseek-chat  Q1      0.766667
# 43         16     deepseek-chat  Q2      0.866667
# 44         16  gemini-2.5-flash  Q1      0.250000
# 45         16  gemini-2.5-flash  Q2      0.000000
# 46         16           gpt-5.1  Q1      0.533333
# 47         16           gpt-5.1  Q2      0.000000
# 48         18     deepseek-chat  Q1      0.166667
# 49         18     deepseek-chat  Q2      0.733333
# 50         18  gemini-2.5-flash  Q1      0.000000
# 51         18  gemini-2.5-flash  Q2      0.000000
# 52         18           gpt-5.1  Q1      1.000000
# 53         18           gpt-5.1  Q2      0.000000
# 54         20     deepseek-chat  Q1      0.000000
# 55         20     deepseek-chat  Q2      1.000000
# 56         20     deepseek-chat  Q3      0.000000
# 57         20     deepseek-chat  Q4      0.000000
# 58         20     deepseek-chat  Q5      0.000000
# 59         20     deepseek-chat  Q6      0.166667
# 60         20     deepseek-chat  Q7      0.000000
# 61         20     deepseek-chat  Q8      0.000000
# 62         20     deepseek-chat  Q9      0.000000
# 63         20  gemini-2.5-flash  Q1      0.666667
# 64         20  gemini-2.5-flash  Q2      0.000000
# 65         20  gemini-2.5-flash  Q3      0.000000
# 66         20  gemini-2.5-flash  Q4      0.000000
# 67         20  gemini-2.5-flash  Q5      0.000000
# 68         20  gemini-2.5-flash  Q6      0.000000
# 69         20  gemini-2.5-flash  Q7      0.000000
# 70         20  gemini-2.5-flash  Q8      0.000000
# 71         20  gemini-2.5-flash  Q9      0.000000
# 72         20           gpt-5.1  Q1      1.000000
# 73         20           gpt-5.1  Q2      0.000000
# 74         20           gpt-5.1  Q3      0.000000
# 75         20           gpt-5.1  Q4      0.000000
# 76         20           gpt-5.1  Q5      0.000000
# 77         20           gpt-5.1  Q6      0.000000
# 78         20           gpt-5.1  Q7      0.000000
# 79         20           gpt-5.1  Q8      0.000000
# 80         20           gpt-5.1  Q9      0.000000
# 81         22     deepseek-chat  Q1      0.000000
# 82         22     deepseek-chat  Q2      1.000000
# 83         22  gemini-2.5-flash  Q1      0.000000
# 84         22  gemini-2.5-flash  Q2      0.000000
# 85         22           gpt-5.1  Q1      1.000000
# 86         22           gpt-5.1  Q2      0.000000
# 87         24     deepseek-chat  Q1      0.900000
# 88         24     deepseek-chat  Q2      1.000000
# 89         24  gemini-2.5-flash  Q1      0.000000
# 90         24  gemini-2.5-flash  Q2      0.000000
# 91         24           gpt-5.1  Q1      1.000000
# 92         24           gpt-5.1  Q2      0.000000
# 93         26     deepseek-chat  Q1      0.433333
# 94         26     deepseek-chat  Q2      1.000000
# 95         26  gemini-2.5-flash  Q1      0.166667
# 96         26  gemini-2.5-flash  Q2      0.000000
# 97         26           gpt-5.1  Q1      1.000000
# 98         26           gpt-5.1  Q2      0.433333
# 99         28     deepseek-chat  Q1      0.533333
# 100        28     deepseek-chat  Q2      1.000000
# 101        28  gemini-2.5-flash  Q1      0.016667
# 102        28  gemini-2.5-flash  Q2      0.000000
# 103        28           gpt-5.1  Q1      1.000000
# 104        28           gpt-5.1  Q2      0.333333
# 105        30     deepseek-chat  Q1      1.000000
# 106        30     deepseek-chat  Q2      1.000000
# 107        30  gemini-2.5-flash  Q1      0.233333
# 108        30  gemini-2.5-flash  Q2      0.016667
# 109        30           gpt-5.1  Q1      0.733333
# 110        30           gpt-5.1  Q2      0.900000
# 111        32     deepseek-chat  Q1      1.000000
# 112        32     deepseek-chat  Q2      1.000000
# 113        32  gemini-2.5-flash  Q1      0.000000
# 114        32  gemini-2.5-flash  Q2      0.016667
# 115        32           gpt-5.1  Q1      0.700000
# 116        32           gpt-5.1  Q2      0.900000
# 117        34     deepseek-chat  Q1      1.000000
# 118        34     deepseek-chat  Q2      1.000000
# 119        34  gemini-2.5-flash  Q1      0.000000
# 120        34  gemini-2.5-flash  Q2      0.000000
# 121        34           gpt-5.1  Q1      0.533333
# 122        34           gpt-5.1  Q2      1.000000
# 123        36     deepseek-chat  Q1      0.400000
# 124        36     deepseek-chat  Q2      1.000000
# 125        36  gemini-2.5-flash  Q1      0.016667
# 126        36  gemini-2.5-flash  Q2      0.000000
# 127        36           gpt-5.1  Q1      0.933333
# 128        36           gpt-5.1  Q2      1.000000
# 129        38     deepseek-chat  Q1      0.766667
# 130        38     deepseek-chat  Q2      1.000000
# 131        38  gemini-2.5-flash  Q1      0.033333
# 132        38  gemini-2.5-flash  Q2      0.000000
# 133        38           gpt-5.1  Q1      1.000000
# 134        38           gpt-5.1  Q2      1.000000
# 135        40     deepseek-chat  Q1      0.566667
# 136        40     deepseek-chat  Q2      1.000000
# 137        40     deepseek-chat  Q3      0.666667
# 138        40     deepseek-chat  Q4      0.100000
# 139        40     deepseek-chat  Q5      0.000000
# 140        40     deepseek-chat  Q6      0.000000
# 141        40     deepseek-chat  Q7      0.166667
# 142        40     deepseek-chat  Q8      0.000000
# 143        40     deepseek-chat  Q9      0.000000
# 144        40  gemini-2.5-flash  Q1      0.266667
# 145        40  gemini-2.5-flash  Q2      0.000000
# 146        40  gemini-2.5-flash  Q3      0.000000
# 147        40  gemini-2.5-flash  Q4      0.000000
# 148        40  gemini-2.5-flash  Q5      0.000000
# 149        40  gemini-2.5-flash  Q6      0.000000
# 150        40  gemini-2.5-flash  Q7      0.000000
# 151        40  gemini-2.5-flash  Q8      0.000000
# 152        40  gemini-2.5-flash  Q9      0.000000
# 153        40           gpt-5.1  Q1      0.933333
# 154        40           gpt-5.1  Q2      1.000000
# 155        40           gpt-5.1  Q3      0.000000
# 156        40           gpt-5.1  Q4      0.000000
# 157        40           gpt-5.1  Q5      0.000000
# 158        40           gpt-5.1  Q6      0.000000
# 159        40           gpt-5.1  Q7      0.000000
# 160        40           gpt-5.1  Q8      0.000000
# 161        40           gpt-5.1  Q9      0.000000
# 162        42     deepseek-chat  Q1      1.000000
# 163        42     deepseek-chat  Q2      1.000000
# 164        42  gemini-2.5-flash  Q1      0.266667
# 165        42  gemini-2.5-flash  Q2      0.016667
# 166        42           gpt-5.1  Q1      1.000000
# 167        42           gpt-5.1  Q2      1.000000
# 168        44     deepseek-chat  Q1      0.366667
# 169        44     deepseek-chat  Q2      1.000000
# 170        44  gemini-2.5-flash  Q1      0.333333
# 171        44  gemini-2.5-flash  Q2      0.000000
# 172        44           gpt-5.1  Q1      0.966667
# 173        44           gpt-5.1  Q2      1.000000
# 174        46     deepseek-chat  Q1      0.333333
# 175        46     deepseek-chat  Q2      1.000000
# 176        46  gemini-2.5-flash  Q1      0.016667
# 177        46  gemini-2.5-flash  Q2      0.000000
# 178        46           gpt-5.1  Q1      1.000000
# 179        46           gpt-5.1  Q2      1.000000
# 180        48     deepseek-chat  Q1      0.733333
# 181        48     deepseek-chat  Q2      1.000000
# 182        48  gemini-2.5-flash  Q1      0.000000
# 183        48  gemini-2.5-flash  Q2      0.016667
# 184        48           gpt-5.1  Q1      1.000000
# 185        48           gpt-5.1  Q2      1.000000
# 186        50     deepseek-chat  Q1      0.800000
# 187        50     deepseek-chat  Q2      1.000000
# 188        50  gemini-2.5-flash  Q1      0.700000
# 189        50  gemini-2.5-flash  Q2      0.100000
# 190        50           gpt-5.1  Q1      0.800000
# 191        50           gpt-5.1  Q2      1.000000
# 192        60     deepseek-chat  Q3      0.000000
# 193        60     deepseek-chat  Q4      0.066667
# 194        60     deepseek-chat  Q5      0.033333
# 195        60     deepseek-chat  Q6      0.000000
# 196        60     deepseek-chat  Q7      0.066667
# 197        60     deepseek-chat  Q8      0.000000
# 198        60     deepseek-chat  Q9      0.000000
# 199        60  gemini-2.5-flash  Q3      0.000000
# 200        60  gemini-2.5-flash  Q4      0.000000
# 201        60  gemini-2.5-flash  Q5      0.000000
# 202        60  gemini-2.5-flash  Q6      0.000000
# 203        60  gemini-2.5-flash  Q7      0.000000
# 204        60  gemini-2.5-flash  Q8      0.000000
# 205        60  gemini-2.5-flash  Q9      0.000000
# 206        60           gpt-5.1  Q3      0.000000
# 207        60           gpt-5.1  Q4      0.000000
# 208        60           gpt-5.1  Q5      0.000000
# 209        60           gpt-5.1  Q6      0.000000
# 210        60           gpt-5.1  Q7      0.000000
# 211        60           gpt-5.1  Q8      0.000000
# 212        60           gpt-5.1  Q9      0.000000
# 213        80     deepseek-chat  Q3      0.000000
# 214        80     deepseek-chat  Q4      0.233333
# 215        80     deepseek-chat  Q5      0.433333
# 216        80     deepseek-chat  Q6      0.100000
# 217        80     deepseek-chat  Q7      0.166667
# 218        80     deepseek-chat  Q8      0.166667
# 219        80     deepseek-chat  Q9      0.000000
# 220        80  gemini-2.5-flash  Q3      0.000000
# 221        80  gemini-2.5-flash  Q4      0.000000
# 222        80  gemini-2.5-flash  Q5      0.266667
# 223        80  gemini-2.5-flash  Q6      0.100000
# 224        80  gemini-2.5-flash  Q7      0.000000
# 225        80  gemini-2.5-flash  Q8      0.000000
# 226        80  gemini-2.5-flash  Q9      0.000000
# 227        80           gpt-5.1  Q3      0.000000
# 228        80           gpt-5.1  Q4      0.000000
# 229        80           gpt-5.1  Q5      0.000000
# 230        80           gpt-5.1  Q6      0.000000
# 231        80           gpt-5.1  Q7      0.000000
# 232        80           gpt-5.1  Q8      0.000000
# 233        80           gpt-5.1  Q9      0.000000
# 234       100     deepseek-chat  Q3      1.000000
# 235       100     deepseek-chat  Q4      0.833333
# 236       100     deepseek-chat  Q5      1.000000
# 237       100     deepseek-chat  Q6      0.866667
# 238       100     deepseek-chat  Q7      0.666667
# 239       100     deepseek-chat  Q8      0.166667
# 240       100     deepseek-chat  Q9      0.366667
# 241       100  gemini-2.5-flash  Q3      0.833333
# 242       100  gemini-2.5-flash  Q4      0.033333
# 243       100  gemini-2.5-flash  Q5      0.166667
# 244       100  gemini-2.5-flash  Q6      0.566667
# 245       100  gemini-2.5-flash  Q7      0.516667
# 246       100  gemini-2.5-flash  Q8      0.433333
# 247       100  gemini-2.5-flash  Q9      0.300000
# 248       100           gpt-5.1  Q3      0.000000
# 249       100           gpt-5.1  Q4      0.000000
# 250       100           gpt-5.1  Q5      0.000000
# 251       100           gpt-5.1  Q6      0.000000
# 252       100           gpt-5.1  Q7      0.000000
# 253       100           gpt-5.1  Q8      0.233333
# 254       100           gpt-5.1  Q9      0.033333
# 255       120     deepseek-chat  Q3      1.000000
# 256       120     deepseek-chat  Q4      0.800000
# 257       120     deepseek-chat  Q5      1.000000
# 258       120     deepseek-chat  Q6      0.300000
# 259       120     deepseek-chat  Q7      0.966667
# 260       120     deepseek-chat  Q8      0.766667
# 261       120     deepseek-chat  Q9      0.333333
# 262       120  gemini-2.5-flash  Q3      0.666667
# 263       120  gemini-2.5-flash  Q4      0.233333
# 264       120  gemini-2.5-flash  Q5      0.166667
# 265       120  gemini-2.5-flash  Q6      0.600000
# 266       120  gemini-2.5-flash  Q7      0.733333
# 267       120  gemini-2.5-flash  Q8      0.066667
# 268       120  gemini-2.5-flash  Q9      0.366667
# 269       120           gpt-5.1  Q3      0.000000
# 270       120           gpt-5.1  Q4      0.033333
# 271       120           gpt-5.1  Q5      0.066667
# 272       120           gpt-5.1  Q6      0.000000
# 273       120           gpt-5.1  Q7      0.033333
# 274       120           gpt-5.1  Q8      0.000000
# 275       120           gpt-5.1  Q9      0.200000
# 276       140     deepseek-chat  Q3      1.000000
# 277       140     deepseek-chat  Q4      0.933333
# 278       140     deepseek-chat  Q5      0.966667
# 279       140     deepseek-chat  Q6      0.866667
# 280       140     deepseek-chat  Q7      0.933333
# 281       140     deepseek-chat  Q8      0.833333
# 282       140     deepseek-chat  Q9      0.833333
# 283       140  gemini-2.5-flash  Q3      0.366667
# 284       140  gemini-2.5-flash  Q4      0.033333
# 285       140  gemini-2.5-flash  Q5      0.633333
# 286       140  gemini-2.5-flash  Q6      0.266667
# 287       140  gemini-2.5-flash  Q7      0.700000
# 288       140  gemini-2.5-flash  Q8      0.200000
# 289       140  gemini-2.5-flash  Q9      0.100000
# 290       140           gpt-5.1  Q3      0.000000
# 291       140           gpt-5.1  Q4      0.033333
# 292       140           gpt-5.1  Q5      0.000000
# 293       140           gpt-5.1  Q6      0.266667
# 294       140           gpt-5.1  Q7      0.033333
# 295       140           gpt-5.1  Q8      0.033333
# 296       140           gpt-5.1  Q9      0.300000
# 297       160     deepseek-chat  Q3      1.000000
# 298       160     deepseek-chat  Q4      0.666667
# 299       160     deepseek-chat  Q5      1.000000
# 300       160     deepseek-chat  Q6      0.200000
# 301       160     deepseek-chat  Q7      0.800000
# 302       160     deepseek-chat  Q8      0.866667
# 303       160     deepseek-chat  Q9      0.900000
# 304       160  gemini-2.5-flash  Q3      0.566667
# 305       160  gemini-2.5-flash  Q4      0.200000
# 306       160  gemini-2.5-flash  Q5      0.800000
# 307       160  gemini-2.5-flash  Q6      0.400000
# 308       160  gemini-2.5-flash  Q7      0.700000
# 309       160  gemini-2.5-flash  Q8      0.066667
# 310       160  gemini-2.5-flash  Q9      0.033333
# 311       160           gpt-5.1  Q3      0.000000
# 312       160           gpt-5.1  Q4      0.533333
# 313       160           gpt-5.1  Q5      0.833333
# 314       160           gpt-5.1  Q6      0.933333
# 315       160           gpt-5.1  Q7      0.966667
# 316       160           gpt-5.1  Q8      0.900000
# 317       160           gpt-5.1  Q9      1.000000
# 318       180     deepseek-chat  Q3      0.900000
# 319       180     deepseek-chat  Q4      1.000000
# 320       180     deepseek-chat  Q5      1.000000
# 321       180     deepseek-chat  Q6      0.833333
# 322       180     deepseek-chat  Q7      1.000000
# 323       180     deepseek-chat  Q8      1.000000
# 324       180     deepseek-chat  Q9      1.000000
# 325       180  gemini-2.5-flash  Q3      0.033333
# 326       180  gemini-2.5-flash  Q4      0.000000
# 327       180  gemini-2.5-flash  Q5      0.666667
# 328       180  gemini-2.5-flash  Q6      0.166667
# 329       180  gemini-2.5-flash  Q7      0.466667
# 330       180  gemini-2.5-flash  Q8      0.400000
# 331       180  gemini-2.5-flash  Q9      0.000000
# 332       180           gpt-5.1  Q3      0.000000
# 333       180           gpt-5.1  Q4      0.000000
# 334       180           gpt-5.1  Q5      0.066667
# 335       180           gpt-5.1  Q6      0.266667
# 336       180           gpt-5.1  Q7      0.233333
# 337       180           gpt-5.1  Q8      0.266667
# 338       180           gpt-5.1  Q9      0.033333
# 339       200     deepseek-chat  Q3      1.000000
# 340       200     deepseek-chat  Q4      1.000000
# 341       200     deepseek-chat  Q5      1.000000
# 342       200     deepseek-chat  Q6      0.333333
# 343       200     deepseek-chat  Q7      0.866667
# 344       200     deepseek-chat  Q8      1.000000
# 345       200     deepseek-chat  Q9      1.000000
# 346       200  gemini-2.5-flash  Q3      0.433333
# 347       200  gemini-2.5-flash  Q4      0.333333
# 348       200  gemini-2.5-flash  Q5      0.466667
# 349       200  gemini-2.5-flash  Q6      0.533333
# 350       200  gemini-2.5-flash  Q7      0.166667
# 351       200  gemini-2.5-flash  Q8      0.100000
# 352       200  gemini-2.5-flash  Q9      0.066667
# 353       200           gpt-5.1  Q3      0.166667
# 354       200           gpt-5.1  Q4      0.300000
# 355       200           gpt-5.1  Q5      0.033333
# 356       200           gpt-5.1  Q6      0.100000
# 357       200           gpt-5.1  Q7      0.233333
# 358       200           gpt-5.1  Q8      0.600000
# 359       200           gpt-5.1  Q9      0.066667
# 360       220     deepseek-chat  Q3      1.000000
# 361       220     deepseek-chat  Q4      1.000000
# 362       220     deepseek-chat  Q5      1.000000
# 363       220     deepseek-chat  Q6      0.966667
# 364       220     deepseek-chat  Q7      1.000000
# 365       220     deepseek-chat  Q8      1.000000
# 366       220     deepseek-chat  Q9      1.000000
# 367       220  gemini-2.5-flash  Q3      0.300000
# 368       220  gemini-2.5-flash  Q4      0.466667
# 369       220  gemini-2.5-flash  Q5      0.833333
# 370       220  gemini-2.5-flash  Q6      0.800000
# 371       220  gemini-2.5-flash  Q7      0.900000
# 372       220  gemini-2.5-flash  Q8      0.000000
# 373       220  gemini-2.5-flash  Q9      0.066667
# 374       220           gpt-5.1  Q3      0.033333
# 375       220           gpt-5.1  Q4      0.666667
# 376       220           gpt-5.1  Q5      0.800000
# 377       220           gpt-5.1  Q6      0.866667
# 378       220           gpt-5.1  Q7      0.900000
# 379       220           gpt-5.1  Q8      0.666667
# 380       220           gpt-5.1  Q9      0.766667
# 381       240     deepseek-chat  Q3      0.533333
# 382       240     deepseek-chat  Q4      1.000000
# 383       240     deepseek-chat  Q5      1.000000
# 384       240     deepseek-chat  Q6      0.833333
# 385       240     deepseek-chat  Q7      1.000000
# 386       240     deepseek-chat  Q8      1.000000
# 387       240     deepseek-chat  Q9      1.000000
# 388       240  gemini-2.5-flash  Q3      0.533333
# 389       240  gemini-2.5-flash  Q4      0.300000
# 390       240  gemini-2.5-flash  Q5      0.800000
# 391       240  gemini-2.5-flash  Q6      0.066667
# 392       240  gemini-2.5-flash  Q7      0.400000
# 393       240  gemini-2.5-flash  Q8      0.233333
# 394       240  gemini-2.5-flash  Q9      0.000000
# 395       240           gpt-5.1  Q3      0.866667
# 396       240           gpt-5.1  Q4      0.166667
# 397       240           gpt-5.1  Q5      0.233333
# 398       240           gpt-5.1  Q6      0.966667
# 399       240           gpt-5.1  Q7      0.866667
# 400       240           gpt-5.1  Q8      0.733333
# 401       240           gpt-5.1  Q9      0.700000
# 402       260     deepseek-chat  Q3      1.000000
# 403       260     deepseek-chat  Q4      1.000000
# 404       260     deepseek-chat  Q5      1.000000
# 405       260     deepseek-chat  Q6      1.000000
# 406       260     deepseek-chat  Q7      1.000000
# 407       260     deepseek-chat  Q8      0.800000
# 408       260     deepseek-chat  Q9      1.000000
# 409       260  gemini-2.5-flash  Q3      0.766667
# 410       260  gemini-2.5-flash  Q4      0.133333
# 411       260  gemini-2.5-flash  Q5      0.500000
# 412       260  gemini-2.5-flash  Q6      0.433333
# 413       260  gemini-2.5-flash  Q7      0.966667
# 414       260  gemini-2.5-flash  Q8      0.300000
# 415       260  gemini-2.5-flash  Q9      0.366667
# 416       260           gpt-5.1  Q3      0.766667
# 417       260           gpt-5.1  Q4      0.666667
# 418       260           gpt-5.1  Q5      0.466667
# 419       260           gpt-5.1  Q6      0.900000
# 420       260           gpt-5.1  Q7      0.966667
# 421       260           gpt-5.1  Q8      0.966667
# 422       260           gpt-5.1  Q9      0.866667
# 423       280     deepseek-chat  Q3      1.000000
# 424       280     deepseek-chat  Q4      1.000000
# 425       280     deepseek-chat  Q5      1.000000
# 426       280     deepseek-chat  Q6      1.000000
# 427       280     deepseek-chat  Q7      1.000000
# 428       280     deepseek-chat  Q8      1.000000
# 429       280     deepseek-chat  Q9      1.000000
# 430       280  gemini-2.5-flash  Q3      0.800000
# 431       280  gemini-2.5-flash  Q4      0.233333
# 432       280  gemini-2.5-flash  Q5      0.633333
# 433       280  gemini-2.5-flash  Q6      0.333333
# 434       280  gemini-2.5-flash  Q7      0.766667
# 435       280  gemini-2.5-flash  Q8      0.033333
# 436       280  gemini-2.5-flash  Q9      0.133333
# 437       280           gpt-5.1  Q3      0.933333
# 438       280           gpt-5.1  Q4      1.000000
# 439       280           gpt-5.1  Q5      0.966667
# 440       280           gpt-5.1  Q6      0.966667
# 441       280           gpt-5.1  Q7      1.000000
# 442       280           gpt-5.1  Q8      0.800000
# 443       280           gpt-5.1  Q9      0.466667
# 444       300     deepseek-chat  Q3      1.000000
# 445       300     deepseek-chat  Q4      1.000000
# 446       300     deepseek-chat  Q5      1.000000
# 447       300     deepseek-chat  Q6      1.000000
# 448       300     deepseek-chat  Q7      1.000000
# 449       300     deepseek-chat  Q8      1.000000
# 450       300     deepseek-chat  Q9      1.000000
# 451       300  gemini-2.5-flash  Q3      0.733333
# 452       300  gemini-2.5-flash  Q4      0.633333
# 453       300  gemini-2.5-flash  Q5      0.866667
# 454       300  gemini-2.5-flash  Q6      0.833333
# 455       300  gemini-2.5-flash  Q7      0.666667
# 456       300  gemini-2.5-flash  Q8      0.900000
# 457       300  gemini-2.5-flash  Q9      0.600000
# 458       300           gpt-5.1  Q3      0.100000
# 459       300           gpt-5.1  Q4      0.733333
# 460       300           gpt-5.1  Q5      0.800000
# 461       300           gpt-5.1  Q6      0.900000
# 462       300           gpt-5.1  Q7      0.533333
# 463       300           gpt-5.1  Q8      1.000000
# 464       300           gpt-5.1  Q9      0.833333
# 465       320     deepseek-chat  Q3      1.000000
# 466       320     deepseek-chat  Q4      1.000000
# 467       320     deepseek-chat  Q5      1.000000
# 468       320     deepseek-chat  Q6      0.600000
# 469       320     deepseek-chat  Q7      1.000000
# 470       320     deepseek-chat  Q8      1.000000
# 471       320     deepseek-chat  Q9      1.000000
# 472       320  gemini-2.5-flash  Q3      0.833333
# 473       320  gemini-2.5-flash  Q4      0.500000
# 474       320  gemini-2.5-flash  Q5      0.633333
# 475       320  gemini-2.5-flash  Q6      0.200000
# 476       320  gemini-2.5-flash  Q7      0.933333
# 477       320  gemini-2.5-flash  Q8      0.300000
# 478       320  gemini-2.5-flash  Q9      0.100000
# 479       320           gpt-5.1  Q3      0.900000
# 480       320           gpt-5.1  Q4      1.000000
# 481       320           gpt-5.1  Q5      1.000000
# 482       320           gpt-5.1  Q6      1.000000
# 483       320           gpt-5.1  Q7      1.000000
# 484       320           gpt-5.1  Q8      1.000000
# 485       320           gpt-5.1  Q9      1.000000
# 486       340     deepseek-chat  Q3      1.000000
# 487       340     deepseek-chat  Q4      1.000000
# 488       340     deepseek-chat  Q5      1.000000
# 489       340     deepseek-chat  Q6      1.000000
# 490       340     deepseek-chat  Q7      1.000000
# 491       340     deepseek-chat  Q8      1.000000
# 492       340     deepseek-chat  Q9      1.000000
# 493       340  gemini-2.5-flash  Q3      0.166667
# 494       340  gemini-2.5-flash  Q4      0.433333
# 495       340  gemini-2.5-flash  Q5      0.533333
# 496       340  gemini-2.5-flash  Q6      0.500000
# 497       340  gemini-2.5-flash  Q7      0.666667
# 498       340  gemini-2.5-flash  Q8      0.100000
# 499       340  gemini-2.5-flash  Q9      0.333333
# 500       340           gpt-5.1  Q3      0.966667
# 501       340           gpt-5.1  Q4      0.800000
# 502       340           gpt-5.1  Q5      0.933333
# 503       340           gpt-5.1  Q6      1.000000
# 504       340           gpt-5.1  Q7      0.966667
# 505       340           gpt-5.1  Q8      0.933333
# 506       340           gpt-5.1  Q9      0.900000
# 507       360     deepseek-chat  Q3      1.000000
# 508       360     deepseek-chat  Q4      1.000000
# 509       360     deepseek-chat  Q5      1.000000
# 510       360     deepseek-chat  Q6      1.000000
# 511       360     deepseek-chat  Q7      1.000000
# 512       360     deepseek-chat  Q8      1.000000
# 513       360     deepseek-chat  Q9      1.000000
# 514       360  gemini-2.5-flash  Q3      0.283333
# 515       360  gemini-2.5-flash  Q4      0.900000
# 516       360  gemini-2.5-flash  Q5      1.000000
# 517       360  gemini-2.5-flash  Q6      0.733333
# 518       360  gemini-2.5-flash  Q7      1.000000
# 519       360  gemini-2.5-flash  Q8      0.366667
# 520       360  gemini-2.5-flash  Q9      0.633333
# 521       360           gpt-5.1  Q3      1.000000
# 522       360           gpt-5.1  Q4      0.866667
# 523       360           gpt-5.1  Q5      0.966667
# 524       360           gpt-5.1  Q6      1.000000
# 525       360           gpt-5.1  Q7      1.000000
# 526       360           gpt-5.1  Q8      0.900000
# 527       360           gpt-5.1  Q9      1.000000
# 528       380     deepseek-chat  Q3      1.000000
# 529       380     deepseek-chat  Q4      1.000000
# 530       380     deepseek-chat  Q5      1.000000
# 531       380     deepseek-chat  Q6      1.000000
# 532       380     deepseek-chat  Q7      1.000000
# 533       380     deepseek-chat  Q8      1.000000
# 534       380     deepseek-chat  Q9      1.000000
# 535       380  gemini-2.5-flash  Q3      0.033333
# 536       380  gemini-2.5-flash  Q4      0.166667
# 537       380  gemini-2.5-flash  Q5      1.000000
# 538       380  gemini-2.5-flash  Q6      0.200000
# 539       380  gemini-2.5-flash  Q7      0.666667
# 540       380  gemini-2.5-flash  Q8      0.033333
# 541       380  gemini-2.5-flash  Q9      0.300000
# 542       380           gpt-5.1  Q3      0.900000
# 543       380           gpt-5.1  Q4      0.866667
# 544       380           gpt-5.1  Q5      1.000000
# 545       380           gpt-5.1  Q6      1.000000
# 546       380           gpt-5.1  Q7      0.966667
# 547       380           gpt-5.1  Q8      0.966667
# 548       380           gpt-5.1  Q9      0.966667
# 549       400     deepseek-chat  Q3      1.000000
# 550       400     deepseek-chat  Q4      1.000000
# 551       400     deepseek-chat  Q5      1.000000
# 552       400     deepseek-chat  Q6      1.000000
# 553       400     deepseek-chat  Q7      1.000000
# 554       400     deepseek-chat  Q8      1.000000
# 555       400     deepseek-chat  Q9      1.000000
# 556       400  gemini-2.5-flash  Q3      0.700000
# 557       400  gemini-2.5-flash  Q4      0.933333
# 558       400  gemini-2.5-flash  Q5      1.000000
# 559       400  gemini-2.5-flash  Q6      0.833333
# 560       400  gemini-2.5-flash  Q7      1.000000
# 561       400  gemini-2.5-flash  Q8      0.633333
# 562       400  gemini-2.5-flash  Q9      0.966667
# 563       400           gpt-5.1  Q3      0.500000
# 564       400           gpt-5.1  Q4      0.866667
# 565       400           gpt-5.1  Q5      1.000000
# 566       400           gpt-5.1  Q6      0.966667
# 567       400           gpt-5.1  Q7      0.933333
# 568       400           gpt-5.1  Q8      1.000000
# 569       400           gpt-5.1  Q9      1.000000
# 570       420     deepseek-chat  Q3      1.000000
# 571       420     deepseek-chat  Q4      1.000000
# 572       420     deepseek-chat  Q5      1.000000
# 573       420     deepseek-chat  Q6      1.000000
# 574       420     deepseek-chat  Q7      1.000000
# 575       420     deepseek-chat  Q8      1.000000
# 576       420     deepseek-chat  Q9      1.000000
# 577       420  gemini-2.5-flash  Q3      0.166667
# 578       420  gemini-2.5-flash  Q4      0.966667
# 579       420  gemini-2.5-flash  Q5      1.000000
# 580       420  gemini-2.5-flash  Q6      0.866667
# 581       420  gemini-2.5-flash  Q7      1.000000
# 582       420  gemini-2.5-flash  Q8      0.933333
# 583       420  gemini-2.5-flash  Q9      0.266667
# 584       420           gpt-5.1  Q3      1.000000
# 585       420           gpt-5.1  Q4      1.000000
# 586       420           gpt-5.1  Q5      1.000000
# 587       420           gpt-5.1  Q6      1.000000
# 588       420           gpt-5.1  Q7      1.000000
# 589       420           gpt-5.1  Q8      1.000000
# 590       420           gpt-5.1  Q9      1.000000
# 591       440     deepseek-chat  Q3      1.000000
# 592       440     deepseek-chat  Q4      1.000000
# 593       440     deepseek-chat  Q5      1.000000
# 594       440     deepseek-chat  Q6      1.000000
# 595       440     deepseek-chat  Q7      1.000000
# 596       440     deepseek-chat  Q8      1.000000
# 597       440     deepseek-chat  Q9      1.000000
# 598       440  gemini-2.5-flash  Q3      0.433333
# 599       440  gemini-2.5-flash  Q4      0.666667
# 600       440  gemini-2.5-flash  Q5      0.600000
# 601       440  gemini-2.5-flash  Q6      0.766667
# 602       440  gemini-2.5-flash  Q7      0.533333
# 603       440  gemini-2.5-flash  Q8      0.400000
# 604       440  gemini-2.5-flash  Q9      0.116667
# 605       440           gpt-5.1  Q3      1.000000
# 606       440           gpt-5.1  Q4      0.966667
# 607       440           gpt-5.1  Q5      0.966667
# 608       440           gpt-5.1  Q6      1.000000
# 609       440           gpt-5.1  Q7      0.966667
# 610       440           gpt-5.1  Q8      1.000000
# 611       440           gpt-5.1  Q9      1.000000
# 612       460     deepseek-chat  Q3      1.000000
# 613       460     deepseek-chat  Q4      1.000000
# 614       460     deepseek-chat  Q5      1.000000
# 615       460     deepseek-chat  Q6      1.000000
# 616       460     deepseek-chat  Q7      1.000000
# 617       460     deepseek-chat  Q8      1.000000
# 618       460     deepseek-chat  Q9      1.000000
# 619       460  gemini-2.5-flash  Q3      0.233333
# 620       460  gemini-2.5-flash  Q4      0.733333
# 621       460  gemini-2.5-flash  Q5      0.766667
# 622       460  gemini-2.5-flash  Q6      0.400000
# 623       460  gemini-2.5-flash  Q7      0.933333
# 624       460  gemini-2.5-flash  Q8      0.300000
# 625       460  gemini-2.5-flash  Q9      0.266667
# 626       460           gpt-5.1  Q3      1.000000
# 627       460           gpt-5.1  Q4      1.000000
# 628       460           gpt-5.1  Q5      1.000000
# 629       460           gpt-5.1  Q6      1.000000
# 630       460           gpt-5.1  Q7      1.000000
# 631       460           gpt-5.1  Q8      1.000000
# 632       460           gpt-5.1  Q9      1.000000
# 633       480     deepseek-chat  Q3      1.000000
# 634       480     deepseek-chat  Q4      1.000000
# 635       480     deepseek-chat  Q5      1.000000
# 636       480     deepseek-chat  Q6      1.000000
# 637       480     deepseek-chat  Q7      1.000000
# 638       480     deepseek-chat  Q8      1.000000
# 639       480     deepseek-chat  Q9      1.000000
# 640       480  gemini-2.5-flash  Q3      0.166667
# 641       480  gemini-2.5-flash  Q4      0.666667
# 642       480  gemini-2.5-flash  Q5      0.900000
# 643       480  gemini-2.5-flash  Q6      0.250000
# 644       480  gemini-2.5-flash  Q7      0.966667
# 645       480  gemini-2.5-flash  Q8      0.500000
# 646       480  gemini-2.5-flash  Q9      0.166667
# 647       480           gpt-5.1  Q3      1.000000
# 648       480           gpt-5.1  Q4      1.000000
# 649       480           gpt-5.1  Q5      1.000000
# 650       480           gpt-5.1  Q6      1.000000
# 651       480           gpt-5.1  Q7      1.000000
# 652       480           gpt-5.1  Q8      1.000000
# 653       480           gpt-5.1  Q9      1.000000
# 654       500     deepseek-chat  Q3      1.000000
# 655       500     deepseek-chat  Q4      1.000000
# 656       500     deepseek-chat  Q5      1.000000
# 657       500     deepseek-chat  Q6      1.000000
# 658       500     deepseek-chat  Q7      1.000000
# 659       500     deepseek-chat  Q8      1.000000
# 660       500     deepseek-chat  Q9      1.000000
# 661       500  gemini-2.5-flash  Q3      1.000000
# 662       500  gemini-2.5-flash  Q4      0.966667
# 663       500  gemini-2.5-flash  Q5      0.966667
# 664       500  gemini-2.5-flash  Q6      1.000000
# 665       500  gemini-2.5-flash  Q7      1.000000
# 666       500  gemini-2.5-flash  Q8      0.900000
# 667       500  gemini-2.5-flash  Q9      0.866667
# 668       500           gpt-5.1  Q3      1.000000
# 669       500           gpt-5.1  Q4      1.000000
# 670       500           gpt-5.1  Q5      1.000000
# 671       500           gpt-5.1  Q6      1.000000
# 672       500           gpt-5.1  Q7      1.000000
# 673       500           gpt-5.1  Q8      1.000000
# 674       500           gpt-5.1  Q9      1.000000

# %% [markdown]
# We plot the change of probability for a distance to be called 'long distance' by LLMs with distance, both model-wise and question-wise.

# %%
def plot(df, model, pos):    
    subset = df[(df['model'] == model)]
    
    plt.figure(figsize=(12,2))
    plt.title(f"{model}", fontsize=12, pad=10)

    Qs = sorted(subset['Q'].unique())
    colors = plt.cm.Set1(np.linspace(0, 1, len(Qs)))

    for i, Q in enumerate(Qs):
        Q_data = subset[subset['Q'] == Q]
        Q_data = Q_data.sort_values('distance')
        
        plt.plot(Q_data['distance'], Q_data['answer_trans'], marker='', linewidth=1.5, \
                color=colors[i], label=f'{Q}', antialiased=True)
    
    plt.xlabel('Distance', fontsize=10)
    plt.ylabel('\'Long-distance\' probability', fontsize=10)
    plt.grid(True, alpha=0.3)
    plt.ylim(0, 1)
    plt.xticks(np.arange(0, 500, 100), fontsize=7)
    plt.yticks(np.arange(0, 1, 0.2), fontsize=7)
    plt.legend(title='Question number', title_fontsize=8, fontsize=7, loc='best', framealpha=0.9)
    filepath = os.path.join(pos, f"{model}.png")
    plt.savefig(filepath, dpi=300, bbox_inches='tight')
    plt.close()

# %%
for model in grouped_result['model'].unique():
    plot(grouped_result, model, 'plots/sce')

# %%
def plot2(df, Q, pos):    
    subset = df[(df['Q'] == Q)]
    
    plt.figure(figsize=(12,2))
    plt.title(f"{Q}", fontsize=12, pad=10)

    models = sorted(subset['model'].unique())
    colors = plt.cm.Set1(np.linspace(0, 1, len(models)))

    for i, model in enumerate(models):
        model_data = subset[subset['model'] == model]
        model_data = model_data.sort_values('distance')
        
        plt.plot(model_data['distance'], model_data['answer_trans'], marker='', linewidth=1.5, \
                color=colors[i], label=f'{model}', antialiased=True)
    
    plt.xlabel('Distance', fontsize=10)
    plt.ylabel('\'Long-distance\' probability', fontsize=10)
    plt.grid(True, alpha=0.3)
    plt.ylim(0, 1)
    plt.xticks(np.arange(0, 500, 100), fontsize=7)
    plt.yticks(np.arange(0, 1, 0.2), fontsize=7)
    plt.legend(title='Model', title_fontsize=8, fontsize=7, loc='best', framealpha=0.9)
    filepath = os.path.join(pos, f"{Q}.png")
    plt.savefig(filepath, dpi=300, bbox_inches='tight')
    plt.close()

# %%
for Q in grouped_result['Q'].unique():
    plot2(grouped_result, Q, 'plots/sce')
